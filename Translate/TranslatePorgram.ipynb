# %% [markdown]
# # python วุ้นแปลภาษา
#
# ## แปลภาษาด้วย code 4 บรรทัด ด้วย package googletrans

# %%
# !pip install googletrans

# %%
from googletrans import Translator

# %%
ts = Translator()
result = ts.translate('안녕하세요.', dest='th') #parameter dest ใช้กำหนดภาษาที่จะแปล

# %%
print(result.origin, ' --> ', result.text)
# Out:
# 안녕하세요.  -->  สวัสดี

# %% [markdown]
# ## พิมพ์ข้อความใน input แล้วแปลเป็นภาษาไทย

# %%
src = input('ข้อความที่ต้องการให้แปล: ')
# Out:
# ข้อความที่ต้องการให้แปล: Hello World!

# %%
result = ts.translate(src, dest='th')
print(result.origin, ' --> ', result.text)
# Out:
# Hello World!  -->  สวัสดีชาวโลก!
